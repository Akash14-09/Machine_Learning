# %%
class Atm :

  #constructor(its a special function -> bcs execute krne ke liye call krne ke jarurat nhi padti)
  def __init__(self):
    # print(id(self))
    self.pin = ''
    self.balance = 100000 #nam ke aage variable ke self lgega hamesha
    self.menu()

  def menu(self):
    user_input = input("""
    Hii how can i help you ?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit

    """)

    if user_input == '1':
      self.create_pin()

    elif user_input == '2':
      self.change_pin()

    elif user_input == '3':
      self.check_balance()

    elif user_input == '4':
      self.withdraw()

    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.balnce = user_balance

    print('pin created successfully')
    self.menu()


  def change_pin(self):
    old_pin = input('Enter Old Pin')
    if old_pin == self.pin:
      #let user change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')
      self.menu()
    else :
      print('No you cant change your pin')
      self.menu()


  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('Your Balance is' , self.balance)
    else:
      print('Warning :- WRONG PIN DETECTED')


  def withdraw(self):
    user_pin = input('Enter your pin')
    if user_pin == self.pin:
      #allowing you to withdraw
      amount = int(input('enter your amount'))

      if amount <= self.balance :
        self.balance = self.balance - amount
        print('withdrawl successful -> ', self.balance)
      else:
        print('Dont have enough balance')
    else:
      print('WARNING - Wrong Pin Detected')
    self.menu()

# %%
obj1 = Atm()
# Out:
# WARNING - Wrong Pin Detected
# pin created successfully
# withdrawl successful ->  90000

# %%
class Atm:

  # constructor(special function)->superpower ->
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.balance = 0
    #self.menu()

  def menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.balance = user_balance

    print('pin created successfully')
    self.menu()

  def change_pin():
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')
      self.menu()
    else:
      print('nai karne de sakta re baba')
      self.menu()

  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is ',self.balance)
    else:
      print('chal nikal yahan se')

  def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.balance:
        self.balance = self.balance - amount
        print('withdrawl successful.balance is',self.balance)
      else:
        print('abe garib')
    else:
      print('sale chor')
    self.menu()

# %%
obj2 = Atm()
# Out:
# 132418184927312

# %%
L = [1,2,3]
len(L) #function bcs outside of the class
L.append()#method bcs its inside in the class
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3796880602.py in <cell line: 0>()
#       1 L = [1,2,3]
#       2 len(L) #function bcs outside of the class
# ----> 3 L.append()#method bcs its inside in the class
#
# TypeError: list.append() takes exactly one argument (0 given)

# %%
class Temp:
  def __init__(self):
    print('hello')

obj = Temp()
#constructor def -> constructor is used to write configration related code
#you cant rename constuctor in python
#class ke andr ki sari chizen class ka obj hi access kr skta hai
# Out:
# hello

# %%
class Fraction:

  #parameterized constructor
  def __int__(self,x,y):
    self.num = x
    self.den = y


  def __str__(self):
    return '{}/{}'.format(self.num,self.den)

  def __add__(self,other):
    num_num = self.num.other,den + other.num*self.den
    new_den = self.den*other.den

    return '{}/{}'.format(new_sum , new_den)

  def __sub__(self,other):
  num_num = self.num.other,den - other.num*self.den
  new_den = self.den*other.den

  return '{}/{}'.format(new_sum , new_den)

  def __mul__(self,other):
  num_sum = self.num * other.num
  new_den = self.den*other.den

  return '{}/{}'.format(new_sum , new_den)


  def __truediv__(self,other):
  num_sum = self.num * other.den
  new_den = self.den*other.num

  return '{}/{}'.format(new_sum , new_den)

  def convert_to_decimal(self):
    return self.num/self.den

# %%
fr1 = Fraction(3,4)

# %%
print(fr1)

# %%
print(fr1 + fr2)

# %%
print(fr1- fr2)
print(fr1*fr2)
print(fr1 / fr2)
