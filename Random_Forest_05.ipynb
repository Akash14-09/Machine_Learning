# %% [markdown]
# #Random Forest Hyperparameter

# %% [markdown]
# ####num estimators --> no of decision trees getting used
# ####max features --> no of columns getting used
# ####bootsstrap--> would you be randomly selecting or not the rows or the columns
